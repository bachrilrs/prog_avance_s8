# %% [markdown]
# <h1 style="color: indianred;text-align: center;">Using Pandas </h1>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
df = pd.read_csv("../data/Athletes_summer_games.csv")

df.head()
# Out:
#    Unnamed: 0                                Name Sex   Age            Team  \
# 0           0                           A Dijiang   M  24.0           China
# 1           1                            A Lamusi   M  23.0           China
# 2           2                 Gunnar Nielsen Aaby   M  24.0         Denmark
# 3           3                Edgar Lindenau Aabye   M  34.0  Denmark/Sweden
# 4          26  Cornelia "Cor" Aalten (-Strannood)   F  18.0     Netherlands
#
#    NOC        Games  Year  Season         City       Sport  \
# 0  CHN  1992 Summer  1992  Summer    Barcelona  Basketball
# 1  CHN  2012 Summer  2012  Summer       London        Judo
# 2  DEN  1920 Summer  1920  Summer    Antwerpen    Football
# 3  DEN  1900 Summer  1900  Summer        Paris  Tug-Of-War
# 4  NED  1932 Summer  1932  Summer  Los Angeles   Athletics
#
#                           Event Medal
# 0   Basketball Men's Basketball   NaN
# 1  Judo Men's Extra-Lightweight   NaN
# ...

# %%
df.dropna(inplace=True)
print(df.columns)
df.Age.astype(int).mean()

try:
    df.drop('Unnamed: 0',axis='columns',inplace=True)
except KeyError:
    print('Colonne pas présente.')

df.groupby('Team').describe()
# Out:
# Index(['Name', 'Sex', 'Age', 'Team', 'NOC', 'Games', 'Year', 'Season', 'City',
#        'Sport', 'Event', 'Medal'],
#       dtype='str')
# Colonne pas présente.
#                                 Age                                           \
#                               count       mean        std   min    25%   50%
# Team
# A North American Team           3.0  41.333333   3.055050  38.0  40.00  42.0
# Afghanistan                     2.0  23.000000   2.828427  21.0  22.00  23.0
# Algeria                        17.0  24.117647   2.758676  19.0  23.00  24.0
# Ali-Baba II                     5.0  40.000000  12.227019  26.0  28.00  44.0
# Amateur Athletic Association    5.0  24.600000   2.880972  22.0  23.00  23.0
# ...                             ...        ...        ...   ...    ...   ...
# Winnipeg Shamrocks-1           12.0  26.250000   2.927146  22.0  24.75  25.5
# Yugoslavia                    382.0  24.725131   3.643618  14.0  22.00  24.0
# ...

# %%
df_sport_team = df.groupby(['Team','Sport'])['Age'].mean() # series one dimension
df_sport_team = df.groupby(['Team','Sport'])[['Age']].mean() # df 
df_sport_team['x'] = df.groupby(['Team','Sport'])['Age'].mean() - 2000 # create a column

# When you run a groupby(['Team', 'Sport']), Pandas takes those two columns and moves them into the Index (the row labels). 
# They are no longer considered "Data Columns."
# So shape (...,1)

arbres = df.loc[df.Team.isin(['Algeria','Morocco'])]

l = list(set(df.Team))

if 'Algeria' in l:
    print(l.index('Algeria'))
# Out:
# 633
